# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('startup_funding.csv')
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# 3                 FinTech                      Online Investment
# 4     Fashion and Apparel            Embroiled Clothes For Women
# ...                   ...                                    ...
# 3039                  NaN                                    NaN
# 3040                  NaN                                    NaN
# 3041                  NaN                                    NaN
# 3042                  NaN                                    NaN
# 3043                  NaN                                    NaN
#
#      City  Location                     Investors Name       InvestmentnType  \
# 0         Bengaluru            Tiger Global Management  Private Equity Round
# 1           Gurgaon          Susquehanna Growth Equity              Series C
# 2         Bengaluru              Sequoia Capital India              Series B
# 3         New Delhi                     Vinod Khatumal          Pre-series A
# 4            Mumbai            Sprout Venture Partners            Seed Round
# ...             ...                                ...                   ...
# 3039            NaN        Asia Pacific Internet Group        Private Equity
# 3040            NaN                     KARSEMVEN Fund        Private Equity
# 3041            NaN     Exfinity Fund, GrowX Ventures.        Private Equity
# 3042            NaN                         MakeMyTrip        Private Equity
# 3043            NaN  UK based Group of Angel Investors          Seed Funding
#
#      Amount in USD                            Remarks
# 0     20,00,00,000                                NaN
# 1        80,48,394                                NaN
# 2      1,83,58,860                                NaN
# 3        30,00,000                                NaN
# 4        18,00,000                                NaN
# ...            ...                                ...
# 3039     45,00,000                                NaN
# 3040      8,25,000                Govt backed VC Fund
# 3041     15,00,000                                NaN
# 3042           NaN  Strategic Funding, Minority stake
# 3043      1,40,000                                NaN
#
# [3044 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df.isnull().sum()
# Out:
# Sr No                   0
# Date dd/mm/yyyy         0
# Startup Name            0
# Industry Vertical     171
# SubVertical           936
# City  Location        180
# Investors Name         24
# InvestmentnType         4
# Amount in USD         960
# Remarks              2625
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Sr No                 0.000000
# Date dd/mm/yyyy       0.000000
# Startup Name          0.000000
# Industry Vertical     5.617608
# SubVertical          30.749014
# City  Location        5.913272
# Investors Name        0.788436
# InvestmentnType       0.131406
# Amount in USD        31.537451
# Remarks              86.235217
# dtype: float64

# %%
df.drop(columns=['Remarks'],inplace=True)

# %%
df
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# 3                 FinTech                      Online Investment
# 4     Fashion and Apparel            Embroiled Clothes For Women
# ...                   ...                                    ...
# 3039                  NaN                                    NaN
# 3040                  NaN                                    NaN
# 3041                  NaN                                    NaN
# 3042                  NaN                                    NaN
# 3043                  NaN                                    NaN
#
#      City  Location                     Investors Name       InvestmentnType  \
# 0         Bengaluru            Tiger Global Management  Private Equity Round
# 1           Gurgaon          Susquehanna Growth Equity              Series C
# 2         Bengaluru              Sequoia Capital India              Series B
# 3         New Delhi                     Vinod Khatumal          Pre-series A
# 4            Mumbai            Sprout Venture Partners            Seed Round
# ...             ...                                ...                   ...
# 3039            NaN        Asia Pacific Internet Group        Private Equity
# 3040            NaN                     KARSEMVEN Fund        Private Equity
# 3041            NaN     Exfinity Fund, GrowX Ventures.        Private Equity
# 3042            NaN                         MakeMyTrip        Private Equity
# 3043            NaN  UK based Group of Angel Investors          Seed Funding
#
#      Amount in USD
# 0     20,00,00,000
# 1        80,48,394
# 2      1,83,58,860
# 3        30,00,000
# 4        18,00,000
# ...            ...
# 3039     45,00,000
# 3040      8,25,000
# 3041     15,00,000
# 3042           NaN
# 3043      1,40,000
#
# [3044 rows x 9 columns]

# %%
df.set_index('Sr No',inplace=True)

# %%
df
# Out:
#       Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# Sr No
# 1          09/01/2020                        BYJU’S               E-Tech
# 2          13/01/2020                        Shuttl       Transportation
# 3          09/01/2020                     Mamaearth           E-commerce
# 4          02/01/2020  https://www.wealthbucket.in/              FinTech
# 5          02/01/2020                        Fashor  Fashion and Apparel
# ...               ...                           ...                  ...
# 3040       29/01/2015                    Printvenue                  NaN
# 3041       29/01/2015                      Graphene                  NaN
# 3042       30/01/2015                Mad Street Den                  NaN
# 3043       30/01/2015                     Simplotel                  NaN
# 3044       31/01/2015              couponmachine.in                  NaN
#
#                                  SubVertical City  Location  \
# Sr No
# 1                                 E-learning      Bengaluru
# 2                  App based shuttle service        Gurgaon
# 3      Retailer of baby and toddler products      Bengaluru
# 4                          Online Investment      New Delhi
# 5                Embroiled Clothes For Women         Mumbai
# ...                                      ...            ...
# 3040                                     NaN            NaN
# 3041                                     NaN            NaN
# 3042                                     NaN            NaN
# 3043                                     NaN            NaN
# 3044                                     NaN            NaN
#
#                           Investors Name       InvestmentnType Amount in USD
# Sr No
# 1                Tiger Global Management  Private Equity Round  20,00,00,000
# 2              Susquehanna Growth Equity              Series C     80,48,394
# 3                  Sequoia Capital India              Series B   1,83,58,860
# 4                         Vinod Khatumal          Pre-series A     30,00,000
# 5                Sprout Venture Partners            Seed Round     18,00,000
# ...                                  ...                   ...           ...
# 3040         Asia Pacific Internet Group        Private Equity     45,00,000
# 3041                      KARSEMVEN Fund        Private Equity      8,25,000
# 3042      Exfinity Fund, GrowX Ventures.        Private Equity     15,00,000
# 3043                          MakeMyTrip        Private Equity           NaN
# 3044   UK based Group of Angel Investors          Seed Funding      1,40,000
#
# [3044 rows x 8 columns]

# %%
# simplifying the columns names
df.columns=['date','startup','industry','subvertical','city','investors','round','amount']

# %%
df
# Out:
#              date                       startup             industry  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
# ...                                      ...        ...
# 3040                                     NaN        NaN
# 3041                                     NaN        NaN
# 3042                                     NaN        NaN
# 3043                                     NaN        NaN
# 3044                                     NaN        NaN
#
#                                investors                 round        amount
# Sr No
# 1                Tiger Global Management  Private Equity Round  20,00,00,000
# 2              Susquehanna Growth Equity              Series C     80,48,394
# 3                  Sequoia Capital India              Series B   1,83,58,860
# 4                         Vinod Khatumal          Pre-series A     30,00,000
# 5                Sprout Venture Partners            Seed Round     18,00,000
# ...                                  ...                   ...           ...
# 3040         Asia Pacific Internet Group        Private Equity     45,00,000
# 3041                      KARSEMVEN Fund        Private Equity      8,25,000
# 3042      Exfinity Fund, GrowX Ventures.        Private Equity     15,00,000
# 3043                          MakeMyTrip        Private Equity           NaN
# 3044   UK based Group of Angel Investors          Seed Funding      1,40,000
#
# [3044 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   industry     2873 non-null   object
#  3   subvertical  2108 non-null   object
#  4   city         2864 non-null   object
#  5   investors    3020 non-null   object
#  6   round        3040 non-null   object
#  7   amount       2084 non-null   object
# dtypes: object(8)
# memory usage: 214.0+ KB

# %%
df['amount'].fillna('0',inplace=True)

# %%
df['amount'].isna().sum()
# Out:
# 0

# %%
df['amount']=df['amount'].str.lower().str.replace(',','').replace('undisclosed','0').replace('unknown','0')

# %%
df.shape
# Out:
# (3044, 8)

# %%
df=df[df['amount'].str.isdigit()]

# %%
df
# Out:
#              date                       startup             industry  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
# ...                                      ...        ...
# 3040                                     NaN        NaN
# 3041                                     NaN        NaN
# 3042                                     NaN        NaN
# 3043                                     NaN        NaN
# 3044                                     NaN        NaN
#
#                                investors                 round     amount
# Sr No
# 1                Tiger Global Management  Private Equity Round  200000000
# 2              Susquehanna Growth Equity              Series C    8048394
# 3                  Sequoia Capital India              Series B   18358860
# 4                         Vinod Khatumal          Pre-series A    3000000
# 5                Sprout Venture Partners            Seed Round    1800000
# ...                                  ...                   ...        ...
# 3040         Asia Pacific Internet Group        Private Equity    4500000
# 3041                      KARSEMVEN Fund        Private Equity     825000
# 3042      Exfinity Fund, GrowX Ventures.        Private Equity    1500000
# 3043                          MakeMyTrip        Private Equity          0
# 3044   UK based Group of Angel Investors          Seed Funding     140000
#
# [3029 rows x 8 columns]

# %%
df['amount'].nunique()
# Out:
# 451

# %%
df['amount'].astype('float')
# Out:
# Sr No
# 1       200000000.0
# 2         8048394.0
# 3        18358860.0
# 4         3000000.0
# 5         1800000.0
#            ...
# 3040      4500000.0
# 3041       825000.0
# 3042      1500000.0
# 3043            0.0
# 3044       140000.0
# Name: amount, Length: 3029, dtype: float64

# %%
df['amount']=df['amount'].astype('float')
# Out:
# C:\Users\wajid\AppData\Local\Temp\ipykernel_22708\3595834934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount']=df['amount'].astype('float')

# %%
df
# Out:
#              date                       startup             industry  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
# ...                                      ...        ...
# 3040                                     NaN        NaN
# 3041                                     NaN        NaN
# 3042                                     NaN        NaN
# 3043                                     NaN        NaN
# 3044                                     NaN        NaN
#
#                                investors                 round       amount
# Sr No
# 1                Tiger Global Management  Private Equity Round  200000000.0
# 2              Susquehanna Growth Equity              Series C    8048394.0
# 3                  Sequoia Capital India              Series B   18358860.0
# 4                         Vinod Khatumal          Pre-series A    3000000.0
# 5                Sprout Venture Partners            Seed Round    1800000.0
# ...                                  ...                   ...          ...
# 3040         Asia Pacific Internet Group        Private Equity    4500000.0
# 3041                      KARSEMVEN Fund        Private Equity     825000.0
# 3042      Exfinity Fund, GrowX Ventures.        Private Equity    1500000.0
# 3043                          MakeMyTrip        Private Equity          0.0
# 3044   UK based Group of Angel Investors          Seed Funding     140000.0
#
# [3029 rows x 8 columns]

# %%
def to_inr(dollar):
    inr=dollar*84.73
    return inr/10000000

# %%
df['amount']=df['amount'].apply(to_inr)
# Out:
# C:\Users\wajid\AppData\Local\Temp\ipykernel_22708\4236546661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['amount']=df['amount'].apply(to_inr)

# %%
df
# Out:
#              date                       startup             industry  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
# ...           ...                           ...                  ...
# 3040   29/01/2015                    Printvenue                  NaN
# 3041   29/01/2015                      Graphene                  NaN
# 3042   30/01/2015                Mad Street Den                  NaN
# 3043   30/01/2015                     Simplotel                  NaN
# 3044   31/01/2015              couponmachine.in                  NaN
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
# ...                                      ...        ...
# 3040                                     NaN        NaN
# 3041                                     NaN        NaN
# 3042                                     NaN        NaN
# 3043                                     NaN        NaN
# 3044                                     NaN        NaN
#
#                                investors                 round       amount
# Sr No
# 1                Tiger Global Management  Private Equity Round  1694.600000
# 2              Susquehanna Growth Equity              Series C    68.194042
# 3                  Sequoia Capital India              Series B   155.554621
# 4                         Vinod Khatumal          Pre-series A    25.419000
# 5                Sprout Venture Partners            Seed Round    15.251400
# ...                                  ...                   ...          ...
# 3040         Asia Pacific Internet Group        Private Equity    38.128500
# 3041                      KARSEMVEN Fund        Private Equity     6.990225
# 3042      Exfinity Fund, GrowX Ventures.        Private Equity    12.709500
# 3043                          MakeMyTrip        Private Equity     0.000000
# 3044   UK based Group of Angel Investors          Seed Funding     1.186220
#
# [3029 rows x 8 columns]

# %%
df['date']=pd.to_datetime(df['date'],errors='coerce')
# Out:
# C:\Users\wajid\AppData\Local\Temp\ipykernel_22708\3169875093.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['date']=pd.to_datetime(df['date'],errors='coerce')
# C:\Users\wajid\AppData\Local\Temp\ipykernel_22708\3169875093.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date']=pd.to_datetime(df['date'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3029 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3026 non-null   datetime64[ns]
#  1   startup      3029 non-null   object
#  2   industry     2858 non-null   object
#  3   subvertical  2104 non-null   object
#  4   city         2849 non-null   object
#  5   investors    3005 non-null   object
#  6   round        3027 non-null   object
#  7   amount       3029 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 213.0+ KB

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# date            0.099043
# startup         0.000000
# industry        5.645428
# subvertical    30.538131
# city            5.942555
# investors       0.792341
# round           0.066028
# amount          0.000000
# dtype: float64

# %%
df=df.dropna(subset=['date','startup','industry','city','investors','round','amount'])

# %%
df.shape
# Out:
# (2821, 8)

# %%
df
# Out:
#             date                       startup                    industry  \
# Sr No
# 1     2020-09-01                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-09-01                     Mamaearth                  E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/                     FinTech
# 5     2020-02-01                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
# ...                                      ...        ...
# 2869                                     NaN  Bangalore
# 2870                                     NaN  Bangalore
# 2871                                     NaN  Bangalore
# 2872                                     NaN    Chennai
# 2873                                     NaN      Noida
#
#                                                investors  \
# Sr No
# 1                                Tiger Global Management
# 2                              Susquehanna Growth Equity
# 3                                  Sequoia Capital India
# 4                                         Vinod Khatumal
# 5                                Sprout Venture Partners
# ...                                                  ...
# 2869                                       SAIF Partners
# 2870   Sumit Jain, Aprameya Radhakrishna, Alok Goel, ...
# 2871                                          Rainmatter
# 2872                                         The HR Fund
# 2873            Bessemer Venture Partners, SAIF Partners
#
#                       round       amount
# Sr No
# 1      Private Equity Round  1694.600000
# 2                  Series C    68.194042
# 3                  Series B   155.554621
# 4              Pre-series A    25.419000
# 5                Seed Round    15.251400
# ...                     ...          ...
# 2869         Private Equity    29.655500
# 2870           Seed Funding     0.000000
# 2871           Seed Funding     3.389200
# 2872           Seed Funding     4.236500
# 2873         Private Equity    67.784000
#
# [2821 rows x 8 columns]

# %%
df['startup'].unique()
# Out:
# array(['BYJU’S', 'Shuttl', 'Mamaearth', ..., 'Dazo', 'Tradelab', 'PiQube'],
#       dtype=object)

# %%
df.to_csv('final_startup_funding.csv',index=False)

# %%
df['startup'].nunique()
# Out:
# 2298

# %%
sorted(set(df['startup'].unique()))
# Out:
# ['"BYJU\\\\\'S"',
#  '121Policy',
#  '19th mile',
#  '1Crowd',
#  '1mg',
#  '1mg (Healthkartplus)',
#  '33Coupons',
#  '360Ride',
#  '3Dexter',
#  '3HCare',
#  '3rdFlix',
#  '48East',
#  '4tigo',
#  '5th Vital',
#  '6Degree',
#  '75F',
#  '91SpringBoard',
#  '99Games',
#  '99PerHour',
#  '9Stacks',
#  'A&R Bon Vivants',
#  'ABI Health',
#  'AEON Learning',
#  'AHA Taxis',
#  'AYE Finance',
#  'AadharAPI.com',
#  'Aadyah',
#  'Aahaa',
#  'Aahaa Stores',
#  'Aarav UAV',
#  'Aasaanjobs',
#  'Aashiyaan',
#  'Aavishkaar-Intellecap Group',
#  'AbeRuk',
#  'Abhibus',
#  'Absentia',
#  'Absentia VR',
#  'Ace Turtle',
#  'Ace2three',
#  'Acko',
#  'ActOnMagic',
#  'Actionable Analytics',
#  'Active AI',
#  'Active.ai',
#  'Actofit',
#  'Ad2pro',
#  'AdPushUp',
#  'AdStringO',
#  'AdUrCup',
#  'AdWyze',
#  'Address Health',
#  'AdmitKard',
#  'Advanced Structures India',
#  'Advantage Club',
#  'Advenio',
#  'Adytude',
#  'Aequm',
#  'AerMed',
#  'Affimity',
#  'Affordplan',
#  'Agara Labs',
#  'AgentDesks',
#  'Agricxlab',
#  'Agrostar',
#  'Agrowave',
#  'AirCTO',
#  'AirMed Labs',
#  'AirZaar',
#  'Airpay',
#  'Airwood',
#  'Aisle',
#  'Akosha',
#  'Alef\\\\nMobitech',
#  'AllIzHealth',
#  'Allygrow Technologies',
#  'AlmaConnect',
#  'AlmaMapper',
#  'Alpha Capital',
#  'Alteria Capital',
#  'Alternacare',
#  'Altizone',
#  'Amagi Media Labs',
#  'Ambee',
#  'American Vision',
#  'Amigobulls',
#  'Ampere',
#  'Ampere Vehicles',
#  'Anakage',
#  'Anandakanda',
#  'Anchanto',
#  'Annapurna Finance',
#  'AppBrowzer',
#  'AppDaily',
#  'AppLop',
#  'AppVirality',
#  'Appario Retail Pvt Ltd.',
#  'Appie',
#  'AppilyEver',
#  'Appknox',
#  'Applicate',
#  'Applied Solar Technologies',
#  'Applop',
#  'AppsDaily',
#  'Appvigil',
#  'Arcatron',
#  'Arcatron Mobility',
#  'Ark Robot',
#  'Arkin Net',
#  'Arth DesignBuild',
#  'Arya.ai',
#  'Asia Institute Of Medical Science',
#  'AskMyGift',
#  'Asocon',
#  'Ather Energy',
#  'Athletto',
#  'Atlan',
#  'Atomberg',
#  'Atomberg Technology',
#  'Attune Technologies',
#  'Augrav',
#  'AutoGrid',
#  'AutoSense',
#  'Autobix',
#  'Automation Anywhere',
#  'Autorox.co',
#  'Avagmah',
#  'Avail Finance',
#  'AvailFinance',
#  'Avanti Learning',
#  'Avenue Growth',
#  'Avishkaar Box',
#  'Awaaz De',
#  'Awesummly',
#  'Awfis',
#  'Awign',
#  'Axio',
#  'Axtria',
#  'Aye Finance',
#  'AyeFinance',
#  'Azah',
#  'Azuro',
#  'B9 Beverages',
#  'BHIVE',
#  'BHIVE Workspace',
#  'BRIDGEi2I',
#  'BYG',
#  'BYJU\\\\xe2\\\\x80\\\\x99s',
#  'BYJU’S',
#  'Babajobs',
#  'Baby Berry',
#  'BabyChakra',
#  'Babychakra',
#  'Babygogo',
#  'BabyonBoard',
#  'Badiyajobs',
#  'BaggOut',
#  'Balance App',
#  'Banihal',
#  'Bank Bazaar',
#  'BankBazaar',
#  'BankerBay',
#  'Bats on delivery',
#  'Baxi',
#  'Be U Salons',
#  'BeaconsTalk',
#  'Beardo',
#  'BeatRoute',
#  'BedBathMore',
#  'Belita',
#  'Belong',
#  'Benepik',
#  'Bestdealfinance',
#  'BetaOut',
#  'Betaout',
#  'Better Mortgage',
#  'BetterButter.in',
#  'BetterPlace',
#  'Betterplace',
#  'Bevy',
#  'Beyond Evolution',
#  'Bharat Bazaar',
#  'BharatPe',
#  'BhiveWorkspace',
#  'BiBox',
#  'Bidgely',
#  'Big Basket',
#  'Big Fish Ventures',
#  'BigBasket',
#  'BigStylist',
#  'BigStylist.com',
#  'Bikxie',
#  'Billion Loans',
#  'Bira91',
#  'Biryani Blues',
#  'Biryani By Kilo',
#  'BitGiving',
#  'Biteclub',
#  'Bitla Software',
#  'Biz2Credit',
#  'Bizom',
#  'Bizongo',
#  'Black Soil',
#  'Black White Orange',
#  'Black White Orange Brands',
#  'BlackBuck',
#  'Blackbuck',
#  'Blinge',
#  'BlogBeats',
#  'Blood n Care',
#  'Blowhorn',
#  'Blubox',
#  'Blue Box Media',
#  'Blue Tokai Coffee',
#  'BlueStone',
#  'Bluebirch',
#  'Bluegape',
#  'Bluegape.com',
#  'Board Infinity',
#  'Bobble',
#  'BoiBanit',
#  'BolRealty',
#  'Bollant Industries',
#  'Bolo App',
#  'Bombay Shaving Company',
#  'Bombay Shirt Company',
#  'Bona Vita',
#  'Bonhomia',
#  'Bonphulapl',
#  'Book My Diamond',
#  'Book My Show',
#  'Book Servicing',
#  'BookEventz',
#  'BookMeIn',
#  'BookMyBai',
#  'BookMyShow',
#  'Bottr.me',
#  'Bounty App',
#  'Box My Space',
#  'Box8',
#  'Boxmyspace',
#  'Boxx.ai',
#  'Brick2Wall',
#  'Brigge',
#  'Briston Technomach',
#  'Bro4U',
#  'BroEx',
#  'Broomberg',
#  'Browntape',
#  'BrowserStack',
#  'Bucker',
#  'Buddy',
#  'Buddy4studdy',
#  'Bueno',
#  'BuildSupply',
#  'BuildTraders',
#  'Buildkar',
#  'Buildzar',
#  'Bumper',
#  'Burger Singh',
#  'Buttercups',
#  'Butterfly Interactive',
#  'BuyHatke',
#  'Byju\\\\xe2\\\\x80\\\\x99s',
#  'CAKART.in',
#  'CBREX',
#  'CCAvenue',
#  'CCavenue',
#  'CREO',
#  'CRON Systems',
#  'CaRPM',
#  'Cabsguru',
#  'Call Health',
#  'Campus Diaries',
#  'CanvasFlip',
#  'Canvera',
#  'Canvs',
#  'Capabiliti',
#  'Capillary',
#  'Capillary Tech',
#  'Capita World',
#  'Capital Float',
#  'Capricoast',
#  'Capzest',
#  'CarDekho',
#  'CarTrade',
#  'Caravan Craft',
#  'Carcrew.in',
#  'Care24',
#  'Career Anna',
#  'Career360',
#  'Careongo',
#  'Carl\\\\xe2\\\\x80\\\\x99s Jr',
#  'Cars24',
#  'Cartisan',
#  'Cartrade',
#  'CarveNiche',
#  'Casa2inns',
#  'Cash Suvidha',
#  'CashFree',
#  'Cashe',
#  'Cashflo',
#  'Cashify',
#  'Cashkaro',
#  'Cashkaro.com',
#  'Cashkumar',
#  'Celerix',
#  'Celes Care',
#  'Cerebroz',
#  'Chaayos',
#  'Chai Point',
#  'Chai Thela',
#  'ChaiPoint',
#  'Chakr Innovation',
#  'Changer Mints',
#  'Chargebee',
#  'ChatOnGo',
#  'CheersOye!',
#  'Chefs Basket',
#  'Chevon',
#  'Chikoop',
#  'Chillr',
#  'ChipperSage',
#  'ChqBook',
#  'Chrysalis',
#  'Chumbak',
#  'Chymera VR',
#  'Citrus Payment',
#  'CityFlo',
#  'CityFurnish',
#  'CityShor',
#  'Civilsdaily',
#  'Clapsnslaps',
#  'CleanseCar',
#  'ClearTax',
#  'Cleartax',
#  'Cleartrip',
#  'CleverTap',
#  'Click2Clinic',
#  'Clip App',
#  'Clodura',
#  'Cloud Lending',
#  'Cloudacar',
#  'Cloudcherry Analytics',
#  'Cloudrino',
#  'Clovia',
#  'Clumio',
#  'Co Life',
#  'Codemojo',
#  'CodingLabs',
#  'CoinTribe',
#  'CollPoll',
#  'Collateral Medical',
#  'Collectabillia',
#  'CollegeDekho',
#  'CollegeDunia',
#  'Comarete',
#  'Commeasure',
#  'Commut',
#  'ConfirmTKT',
#  'ConfirmtTkt',
#  'Connaizen',
#  'Connect India',
#  'ConnectAbank',
#  'Consure Medical',
#  'Convegenius',
#  'Cooey',
#  'Cookaroo',
#  'Cookifi',
#  'Coolshare',
#  'Coppre',
#  'Corseco',
#  'CouponRaja',
#  'CoutLoot',
#  'Coutloot',
#  'CoveIoT',
#  'CoverFox',
#  'Coverfox',
#  'CraftsVilla',
#  'Craftstvilla',
#  'Craftsvilla',
#  'Crayon Data',
#  'Creator\\\\xe2\\\\x80\\\\x99s Gurukul',
#  'CredR',
#  'CrediHealth',
#  'Credifiable',
#  'Credihealth',
#  'Credit Mate',
#  'Credit Sudhaar',
#  'Credit Vidya',
#  'CreditMantri',
#  'CreditMate',
#  'CreditSeva',
#  'CreditVidya',
#  'Credright',
#  'Credy',
#  'CroFarm',
#  'Crofarm',
#  'CropIn',
#  'Cropin',
#  'Crossahead',
#  'Crowdera',
#  'Crown-it',
#  'CrownIt',
#  'Crownit',
#  'Cube26',
#  'Cuberoot',
#  'CueMath',
#  'Cuelearn',
#  'Cult',
#  'Cult Fitness',
#  'CultureAlley',
#  'Cupick',
#  'CupoNation',
#  'Curatio',
#  'Cure Fit',
#  'CureFit',
#  'CureInstant',
#  'CureJoy',
#  'Curefit',
#  'Curie Labs',
#  'Curiositi',
#  'Curofy',
#  'Customer360',
#  'CustomerSucessBox',
#  'Customfurnish',
#  'Cyclops',
#  'CyclopsMedtech',
#  'Cygnus Hospitals',
#  'DAAKI',
#  'Daalchini Technologies',
#  'Daily Ninja',
#  'Daily hunt',
#  'DailyHunt',
#  'DailyNinja',
#  'DailyObjects',
#  'DailyRounds',
#  'DarwinBox',
#  'Data Resolve',
#  'DataWeave',
#  'DawaiLelo',
#  'DayBox',
#  'Dazo',
#  'Deal 4Loans',
#  'Deal Street Asia',
#  'Deal4Loans / Wishfin',
#  'Dekkho',
#  'Delhivery',
#  'Delight Foods',
#  'Demyto',
#  'Derbii',
#  'Design Cafe',
#  'DesignBids',
#  'Devourin',
#  'Deyor Camps',
#  'Deyor Rooms',
#  'Dhruva',
#  'Dhruva Space',
#  'Didi',
#  'Digiconectt',
#  'Digilend',
#  'Digio',
#  'Digit',
#  'Digital F5',
#  'Digital Mall Asia',
#  'Dil Mil',
#  'Dipper',
#  'Direct Create',
#  'Diro Labs',
#  'DishCo',
#  'Disprz',
#  'Djubo.com',
#  'DoSelect',
#  'DocPlexus',
#  'DocTalk',
#  'DocsApp',
#  'Doctor Insta',
#  'DoctorInsta',
#  'DogSpot',
#  'Don\\\\xe2\\\\x80\\\\x99t Scratch Your Head',
#  'DoneThing',
#  'DoodhWala',
#  'Doormint',
#  'Doxper',
#  'Dream Wallets',
#  'Dream11',
#  'Drip capital',
#  'DriveSkool',
#  'DriveU',
#  'DriversCart',
#  'Drivezy',
#  'Drivify',
#  'DrivoJoy',
#  'Droom',
#  'Droom.in',
#  'DropKaffe',
#  'Dropkaffe',
#  'Druva',
#  'Duffl',
#  'Dunzo',
#  'EPS',
#  'EPayLater',
#  'ERA',
#  'Early Salary',
#  'EarlySalary',
#  'EarlySalary.com',
#  'Earth Food',
#  'Easy Diner',
#  'EasyEcom',
#  'EasyFix',
#  'EasyGov',
#  'EasyKhaana',
#  'EasyPolicy',
#  'EasyRewardz',
#  'EasyRoads',
#  'Easypolicy',
#  'Eat.Shop.Love',
#  'Eatfresh',
#  'Eatlo',
#  'Eatonomist',
#  'Eattreatonline',
#  'Eazy Coach',
#  'EazyDiner',
#  'Eckovation',
#  'Ecolibriumenergy',
#  'Ecom Express',
#  'Ecozen',
#  'EdTechReview',
#  'Edelweiss',
#  'EdgeFx',
#  'Edu4Share',
#  'EduAce Services',
#  'EduBridge',
#  'EduKart',
#  'EduPristine',
#  'EduRev',
#  'Edureka',
#  'Edurev',
#  'Edyoo',
#  'Elanic',
#  'ElastiRun',
#  'ElasticRun',
#  'ElderAid Wellness',
#  'Elemential',
#  'Elucidata',
#  'Emflux Motors',
#  'Emiza',
#  'Emojifi',
#  'Endless Robotics',
#  'Engineer.ai',
#  'EngineerBabu',
#  'Entropik',
#  'Entropika',
#  'Entropy Innovations',
#  'Envoged',
#  'Epiq Capital',
#  'Eruditus',
#  'Ethinos',
#  'Ethosh',
#  'EureQa',
#  'EvenGini',
#  'EveningFlavors',
#  'Events High',
#  'Explara',
#  'Explore Life traveling',
#  'ExtraCarbon',
#  'ExtraaEdge',
#  'Eywa Media',
#  'EzCred',
#  'Ezetap',
#  'EzySolare',
#  'Ezyhaul',
#  'Ezytruk',
#  'FPL Technologies',
#  'FR8',
#  'FTCash',
#  'FXMartIndia',
#  'FYNE',
#  'FYRE',
#  'Faasos',
#  'Fab Hotels',
#  'FabAlley',
#  'FabHotels',
#  'FabX',
#  'FableStreet',
#  'Fabogo',
#  'Fabulyst',
#  'Faircent',
#  'Faircent.com',
#  'FalconBrick',
#  'FarEye',
#  'FarMart',
#  'Farm Taaza',
#  'FarmLink',
#  'Farmizen',
#  'Fashalot',
#  'Fashionablyin',
#  'Fashionove',
#  'Fashor',
#  'FastFox',
#  'Fastudent',
#  'FeetApart',
#  'FiTraQ',
#  'Fieldassist',
#  'Finance Buddha',
#  'Fincash',
#  'Find My Stay',
#  'FindUrClass',
#  'FindYahan',
#  'FindmeaShoe',
#  'Findow',
#  'Findyahan',
#  'Fingerlix',
#  'Finomena',
#  'Finova Capital',
#  'Fintellix',
#  'Fintobox',
#  'First Eat',
#  'First Moms Club',
#  'FirstCry',
#  'FirstCry.com',
#  'FirstTouch',
#  'Fisdom',
#  'FitMeIn',
#  'Fitcircle',
#  'Fitmein',
#  'Fitnapp',
#  'Fitpass',
#  'Fitso',
#  'Fitternity',
#  'Five Star Group',
#  'FixNix',
#  'Fixy',
#  'Flashdoor',
#  'FlatFurnish',
#  'Flatchat',
#  'Flatpebble',
#  'FleetRover',
#  'FleetX',
#  'Flexiloans',
#  'Flexing It',
#  'FlickBay',
#  'Flickstree',
#  'FlipClass',
#  'Flipkart',
#  'Flipkart.com',
#  'Flixy Games',
#  'Flocareer',
#  'Flochat',
#  'Flutura',
#  'Flyrobe',
#  'Flytxt',
#  'Focus Digit',
#  'FoodAbhi',
#  'FoodTalkIndia',
#  'Foodmemories',
#  'Foodpanda',
#  'ForeverShop',
#  'Formcept',
#  'Fourseven',
#  'Fourth Ambit',
#  'Fourth Partner Energy',
#  'Foyr.com',
#  'Fracktal Works',
#  'Fractal Analytics',
#  'Frapperz',
#  'FreeCharge',
#  'Freedom Smart Labs',
#  'Fresh Food Concepts',
#  'FreshBoxx',
#  'FreshDesk',
#  'FreshMenu',
#  'FreshVnF',
#  'Freshboxx',
#  'Freshdesk',
#  'Freshee',
#  'Freshworks',
#  'Front Desk AI',
#  'FroyoFit',
#  'Frsh',
#  'Ftcash',
#  'Fulfil.IO',
#  'FunOnGo',
#  'Funcart',
#  'Funcastic',
#  'Fundamentor',
#  'FundsIndia.com',
#  'Furdo',
#  'Furlenco',
#  'Fusion Microfinance',
#  'Fyle',
#  'Fyle Technologies',
#  'Fynd',
#  'GIBBS',
#  'GIBSS',
#  'GOQii',
#  'Gaana',
#  'Gaana.com',
#  'Gadgets 360',
#  'Gadgetwood',
#  'Gajty',
#  'Galleri5',
#  'GameXS.in',
#  'GameZop',
#  'Gameezop',
#  'Gaming Monk',
#  'Gamooz',
#  'Gapoon',
#  'Garage On Road',
#  'GenNext Students',
#  'Genextstudents',
#  'Genie',
#  'Genius Corner',
#  'Get My Parking',
#  'Get Simpl',
#  'GetFocus',
#  'GetMyPeon',
#  'GetVee',
#  'Giftxoxo',
#  'GigIndia',
#  'Gingercrush',
#  'Girnar Software',
#  'Glam Studios',
#  'GlamStudios',
#  'Glamrs',
#  'Glassic',
#  'GlowRoad',
#  'Glowroad',
#  'Glowship',
#  'GoBumpr',
#  'GoChoppers',
#  'GoComet',
#  'GoDesi',
#  'GoFro',
#  'GoFynd',
#  'GoGo Truck',
#  'GoJavas',
#  'GoMechanic',
#  'GoPigeon',
#  'GoQii',
#  'GoYaNo',
#  'GoZefo',
#  'Goalwise',
#  'Gobolt',
#  'Godof Hospitals',
#  'GoldFarm',
#  'GolfLAN',
#  'Gomalon',
#  'Good Methods Global',
#  'Goodbox',
#  'Goodera',
#  'Goodservice',
#  'Goomo',
#  'Goqii',
#  'Gozoomo',
#  'Grab',
#  'Grab.in',
#  'GrabOnRent',
#  'Grabhouse',
#  'Gradopedia',
#  'GramCover',
#  'Gramophone',
#  'GrandOpinion',
#  'Gray Routes',
#  'Greenlight Planet',
#  'Grex',
#  'Grey Campus',
#  'Grey Orange',
#  'GreyAtom',
#  'GreytHR',
#  'Gridle',
#  'Grofers',
#  'Grover Zampa',
#  'Grow Fit',
#  'GrowFitter',
#  'Groww',
#  'Guarented',
#  'Guiddoo',
#  'Guidoo',
#  'GuruG Learning',
#  'Gurukul',
#  'Gyaanzone',
#  'GyanDhan',
#  'GymTrekker',
#  'Gympik',
#  'Gympik.com',
#  'HEAL Institute',
#  'HUG Innovations',
#  'HWell24',
#  'HWell24 Plus',
#  'HackerEarth',
#  'HackerRank',
#  'HalaPlay',
#  'HandyTrain',
#  'Hansa Customer Equity',
#  'Hansel io',
#  'Hansel.io',
#  'Happily Unmarried',
#  'HappilyUnmarried',
#  'Happitoo',
#  'Happy EMI',
#  'Happy2Refer',
#  'HappyGoEasy',
#  'Happydemic',
#  'Haptik',
#  'Haqdarshak',
#  'HashTaag',
#  'Hasura',
#  'HeadOut',
#  'Heads Up For Tails',
#  'Healers At Home',
#  'HealthAssure',
#  'HealthCare',
#  'HealthEminds',
#  'HealthEnablr',
#  'HealthFin',
#  'HealthIntel',
#  'HealthKart',
#  'HealthKumbh',
#  'HealthMir',
#  'HealthSutra',
#  'Healthbuds',
#  'Healthcare at Home',
#  'Healthi',
#  'Healthians',
#  'Healthians.com',
#  'HealthifyMe',
#  'Healthifyme',
#  'Healthsignz',
#  'Heckyl',
#  'Hello Curry',
#  'Hello Tax',
#  'HelpChat',
#  'HelpShift',
#  'Helpi',
#  'Heterogenous',
#  'Hevo Data',
#  'HeyBiz',
#  'HeyPillow',
#  'HiJinny',
#  'High Radius',
#  'HighRadius',
#  'Highway Delite',
#  'Hike',
#  'Hike Messenger',
#  'HipBar',
#  'HipCouch',
#  'Hipcask',
#  'Hippily',
#  'Hipship',
#  'HitGrit',
#  'Hitwicket',
#  'HolaChef',
#  'Holachef',
#  'HolidayIQ',
#  'Holidify',
#  'Holisol Logistics',
#  'HomeCapital',
#  'HomeLane',
#  'HomeStudio',
#  'Homelane',
#  'Homergize',
#  'Homers.in',
#  'Hoopy',
#  'Hopping Chef',
#  'Hoppingo',
#  'Hopscotch',
#  'Horntell',
#  'Hotelogix',
#  'Hotify',
#  'House of Msasaba',
#  'Housejoy',
#  'Housing',
#  'Housing.com',
#  'Houssup',
#  'Howdy Ventures',
#  'Hubilo',
#  'Hugefly',
#  'Hungama',
#  'HungerBox',
#  'Hungry Foal',
#  'HyperTrack',
#  'HyperVerge',
#  'Hypernova Interactive',
#  'I Can Stay',
#  'IBSFintech',
#  'ICHR',
#  'ICustomMadeIt',
#  'IDG Ventures',
#  'IDfy',
#  'IFMR Holdings',
#  'IGP.com',
#  'IIM Jobs',
#  'IMAX Program',
#  'IMbesharam',
#  'INDwealth',
#  'ION Energy',
#  'IOTrek',
#  'IQlect',
#  'ISFC',
#  'Icertis',
#  'Idea Bubbles',
#  'IdeaChakki',
#  'IdeaForge',
#  'Ideal Insurance',
#  'Ignis Careers',
#  'ImageProVision',
#  'Imaginate',
#  'Imarticus Learning',
#  'Impact Analytics',
#  'Impact Guru',
#  'ImpactGuru',
#  'InCred Finance',
#  'Inayo',
#  'Inc42',
#  'Inclov',
#  'Increff',
#  'Indee',
#  'India Gifts Portal',
#  'India Lends',
#  'IndiaLends',
#  'Indiamart',
#  'IndianRoots.com',
#  'Indiez',
#  'Indifi',
#  'IndigoLearn',
#  'Indofash',
#  'Indus OS',
#  'IndustryBuying',
#  'Industrybuying',
#  'Infibeam',
#  'Infinite Analytics',
#  'Infisecure',
#  'Infogain',
#  'Infoworks',
#  'Infurnia',
#  'Ink Monk',
#  'Inkmonk',
#  'Inmobi',
#  'Innefu Security Consulting',
#  'Inner Hour',
#  'InnerChef',
#  'InnoNano Research',
#  'Innoplexus',
#  'Innov8',
#  'Innovaccer',
#  'Innovapptive',
#  'Innoviti',
#  'Inshorts',
#  'Insider.in',
#  'InstaLively',
#  'InstaLively.com',
#  'InstaOffice',
#  'InstaSafe',
#  'Instacar',
#  'InstantPay',
#  'Instaproc',
#  'Instavans',
#  'Intelligence Node',
#  'IntelligenceNODE',
#  'Intelligent Interfaces',
#  'Interviewpad',
#  'Intgrea',
#  'Inthree',
#  'Intuit Things',
#  'Inuxu',
#  'Invictus Oncology',
#  'Iqlect',
#  'Ithaka',
#  'Ixigo',
#  'Jay Robotix',
#  'Jaypore',
#  'Jazzmyride',
#  'JetSetGo',
#  'Jhakaas',
#  'Jiffstore',
#  'Jigsaw Academy',
#  'Jivox',
#  'Jiyo Natural',
#  'Jobick',
#  'Jobspire',
#  'JoeHukum',
#  'Johari Shop',
#  'Jolly Food Fellow',
#  'JollyFoodFellow',
#  'Jombay',
#  'Joolz',
#  'Josh Talks',
#  'JoulestoWatts',
#  'Joy by nature',
#  'Juggernaut',
#  'Jugnoo',
#  'Julia Computing',
#  'JumboBasket',
#  'Jumbotail',
#  'Juno Clinic',
#  'Juspay',
#  'Jusride',
#  'Just Buy Live',
#  'JustDoc',
#  'JustLikeNew',
#  ...]

# %%
sorted(set(df['investors'].str.split(',').sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
#  ' Accel Partners & Others',
#  ' Accel Partners & Raghunandan Gangappa',
#  ' Accel Partners & existing investors',
#  ' Accel Partners RNT Associates',
#  ' Accel Partners and G Raghunandan',
#  ' Accel Partners and IDG Ventures',
#  ' Accel Partners and Saama Capital',
#  ' Accel Partners and Tiger Global Management.',
#  ' Accion',
#  ' Accion Venture Lab',
#  ' Acumen Fund',
#  ' Adam D\\\\xe2\\\\x80\\\\x99Angelo',
#  ' Adi Saravanan',
#  ' Adil Allana',
#  ' Aditya Agarwal',
#  ' Aditya Aggarwal',
#  ' Aditya Dev Sood',
#  ' Aditya Malik & Others',
#  ' Aditya Singh',
#  ' Aditya Vazirani',
#  ' Aditya Verma',
#  ' Aditya Vij',
#  ' AdvantEdge Partners',
#  ' Adveq Management',
#  ' Afsal Salu',
#  ' Aijaz Saleem',
#  ' Ajay Bhatia',
#  ' Ajay Data',
#  ' Ajay Lakhotia',
#  ' Ajay Modani',
#  ' Ajay Sarupria',
#  ' Ajeet Khurana',
#  ' Ajeet Khurana & others',
#  ' Akash Bhavsar',
#  ' Akash Garg',
#  ' Akatsuki and Incubate Fund from Japan and Better Capital AngelList syndicate.',
#  ' Akusa Holdings',
#  ' Alagu Periyannan and Karthee Madasamy',
#  ' Alexander Bruehl',
#  ' Alfa Capital',
#  ' Alok Divatia',
#  ' Alok Goel',
#  ' Alok Mittal',
#  ' Alok Mittal & others',
#  ' Alok Mittal and Sachin Bhatia',
#  ' Alok Sharma',
#  ' Alok Srivastava',
#  ' Aloke Bajpai',
#  ' Alphabet\\\\xe2\\\\x80\\\\x99s growth investment arm Capital G and Axis Bank',
#  ' Altimeter Capital',
#  ' Alto Partners',
#  ' Amanpreet Bajaj',
#  ' Amar Arsikere',
#  ' Amaya Capital LLP',
#  ' Ambarish Gupta',
#  ' Ambarish Ray',
#  ' Ambi Parameswaran',
#  ' Ambiga Dhiraj',
#  ' Ameera Shah',
#  ' Amereus Group',
#  ' American Express',
#  ' American Express Ventures',
#  ' Amit Agrawal',
#  ' Amit Banati',
#  ' Amit Banka',
#  ' Amit Dey',
#  ' Amit Gupta',
#  ' Amit Jindal',
#  ' Amit Khanna',
#  ' Amit Khanna (LetsVenture)',
#  ' Amit Kharbanda',
#  ' Amit Manocha',
#  ' Amit Nagar',
#  ' Amit Nanavati',
#  ' Amit Patni',
#  ' Amit Ranjan',
#  ' Amit Ranjan & others',
#  ' Amit Rathore',
#  ' Amit Sandill',
#  ' Amit Singal',
#  ' Amit Sinha',
#  ' Amitpal Bhutani',
#  ' Amiya Pathak',
#  ' Amrendra Reddy and Manish Satnaliwala.',
#  ' Amrish Kumar',
#  ' Amrish Rau',
#  ' Anand Chandrasekaran',
#  ' Anand Kumar',
#  ' Anand Ladsariya',
#  ' Anand Mahindra',
#  ' Anand Rajaraman',
#  ' Anand Sankeshwar',
#  ' Anand Singh',
#  ' Ananda Kallugadde',
#  ' Anandbir Singh',
#  ' Ananth Narayanan',
#  ' Anbu Pandian',
#  ' Andre Hoffman',
#  ' Aneesh Reddy',
#  ' Aneesh Reddy & Teruhide Sato',
#  ' Angie Mahtaney',
#  ' Anil Chopra',
#  ' Anil Gelra',
#  ' Anil Jaggia',
#  ' Anil Jain',
#  ' Anindya Ghose',
#  ' Anirudh Damani',
#  ' Anirudh Rastogi',
#  ' Anirudh Sheth',
#  ' Anish K',
#  ' Anisha Mittal',
#  ' Anita Gupta',
#  ' Anita Hassanandani',
#  ' Anjali Bansal',
#  ' Anjani Prasad',
#  ' Ankit Aditya',
#  ' Ankit Bhati',
#  ' Ankit Nagori',
#  ' Ankit Sharma and others',
#  ' Ankur Capital',
#  ' Ankur Singla',
#  ' Ankur Warikoo',
#  ' Ankush Gupta',
#  ' Ankush Nijhawa',
#  ' Ankush Nijhawan',
#  ' Ankush Saigal',
#  ' Anoop Goyal',
#  ' Anoop Hingorani',
#  ' Anshoo Gaur',
#  ' Anshu Bahadur',
#  ' Anshu Sharma',
#  ' Anshul Jindal',
#  ' Anshuman Das',
#  ' Ant Financial',
#  ' Anthil Ventures & others',
#  ' Anthill Scale Ventures',
#  ' Anthill Ventures',
#  ' Anubhav Verma',
#  ' Anuj Agrawal',
#  ' Anuj Golecha',
#  ' Anuj Gupta',
#  ' Anuj Puri',
#  ' Anuj Sanghi',
#  ' Anuj Srivastava',
#  ' Anupam Mittal',
#  ' Anupam Mittal & other marquee investors',
#  ' Anupam Mittal & others',
#  ' Anupam Tyagi',
#  ' Anurag Gupta',
#  ' Anurag Srivastava',
#  ' Apoletto',
#  ' Apoletto Managers',
#  ' Apoorv Ranjan Sharma',
#  ' Apoorva Patni',
#  ' Appliyifi',
#  ' Aprameya',
#  ' Aprameya Radhakrishna',
#  ' Aprameya Radhakrishnan',
#  ' Apurva Chamaria',
#  ' Apurva Salapuria',
#  ' Apurva Salarpuria',
#  ' Aqeel Ahmed',
#  ' Arathi Krishna',
#  ' Aravind Sanka',
#  ' Arihant Patni',
#  ' Arihant Patni of Patni Family Office',
#  ' Arjun Malhotra',
#  ' Arjun Mehta',
#  ' Arjun Sharmaa',
#  ' Arjun and Rohan Malhotra',
#  ' Arkas Industries',
#  ' Artha India Ventures',
#  ' Arthavida Ventures',
#  ' Artiman Ventures',
#  ' Arts Alliance',
#  ' Arun Garg',
#  ' Arun Khanna',
#  ' Arun Malhotra',
#  ' Arun Sarin',
#  ' Arun Tadanki',
#  ' Arun Venkatachalam',
#  ' Aruna Ganesh Ram',
#  ' Arvind Uppal',
#  ' Ascent Capital',
#  ' Aseem Sood',
#  ' Ashim Mehra',
#  ' Ashish Agrawal',
#  ' Ashish Chand',
#  ' Ashish Dev Kapur',
#  ' Ashish Dhawan',
#  ' Ashish Goenka & Others',
#  ' Ashish Gupta',
#  ' Ashish Hemrajani',
#  ' Ashish Lakhanpal',
#  ' Ashish Toshniwal',
#  ' Ashish Tulsian',
#  ' Ashneer Grover',
#  ' Ashvin Chadha',
#  ' Asian Healthcare fund',
#  ' Aspada',
#  ' Aspada Investment',
#  ' Aspada Ventures',
#  ' Astarc Ventures',
#  ' Atul Goel',
#  ' Atul Nishar',
#  ' Atul Phadnis',
#  ' Augment Ventures',
#  ' Avnish Mehra',
#  ' Avtar Monga',
#  ' Axan Partners',
#  ' Axan Venture',
#  ' Axilor Partners',
#  ' Axilor Ventures',
#  ' Axilor Ventures and Binny Bansal',
#  ' Axis Bank',
#  ' Axis Capital',
#  ' Axis Capital & Others',
#  ' Axon Partners',
#  ' Azmul Haque',
#  ' B Capital',
#  ' BEENEXT',
#  ' BEENEXT Ventures',
#  ' BVR Mohan Reddy',
#  ' Badal Malick',
#  ' Balaji Prabhakar',
#  ' Balamurugan Mani',
#  ' Bamboo Capital Partners',
#  ' Bank to the Future and Funders Club',
#  ' Barkawi Holdings GmbH',
#  ' Basab Pradhan',
#  ' Batlivala & Karani Securities',
#  ' Bedrock Ventures',
#  ' BeeNext',
#  ' Beehive Capital Advisor',
#  ' Beenext',
#  ' Beenext Ventures',
#  ' Beenextan investment fund',
#  ' Beenos',
#  ' Beenos Asia',
#  ' Behram Vakil and Jerxis Vandrevala',
#  ' Bennett Coleman & Co. Ltd',
#  ' Berggruen Holdings',
#  ' Bertelsmann India',
#  ' Bertelsmann India Investments',
#  ' Bertelsmann India Investments Norwest Venture Partners.',
#  ' Bessemer Venture Partners',
#  ' Bharat Gupta',
#  ' Bharat Kedia',
#  ' Bharat Sheth',
#  ' Bharat Vijay',
#  ' Bharti Enterprises',
#  ' Bhavish Aggarwal',
#  ' Bhupen Shah & Others',
#  ' Bhupender Singh',
#  ' Big Data Investments B.V',
#  ' Bijou Kurien',
#  ' Bill & Melinda Gates Foundation',
#  ' Binny Bansal',
#  ' Biz Stone',
#  ' BizReach',
#  ' Blacksoil',
#  ' Blacksoil and Kalaari Capital',
#  ' Blue Cloud Ventures',
#  ' Blue Fog Capital',
#  ' Blume Ventures',
#  ' Blume Ventures & IvyCap Ventures',
#  ' Blume Ventures & Others',
#  ' Blume Ventures & Vaibhav Domkundwar',
#  ' Blume Ventures & others',
#  ' Blume Ventures and Innoven Capital.',
#  ' Blume Ventures and Ujama',
#  ' Blume Ventures.',
#  ' Blume ventures',
#  ' Bobby Reddy',
#  ' Boillot Family Trust',
#  ' Bold Ventures',
#  ' BookMyShow)',
#  ' Boost VC',
#  ' BrahmaX Ventures',
#  ' Brand Capital',
#  ' Bunny Bansal & other investors',
#  ' Burda Principal Investments',
#  ' C31 Ventures',
#  ' CCavenue',
#  ' CDC Group',
#  ' CRV',
#  ' CSC Upshot & Angel investors',
#  ' Calcutta Angels',
#  ' Canaan Partners',
#  ' Capier Investments',
#  ' CapitalG',
#  ' Capricorn Investment Group',
#  ' Capricorn Investment and IFC',
#  ' Caspian and Hivos-Triodos Fund',
#  ' Catamaran Ventures',
#  ' Chanakya Hridaya',
#  ' Chandru Badrinarayanan',
#  ' Chavi Jafa',
#  ' Cheetah Mobile',
#  ' Chennai Angels',
#  ' Chetan Bhagat',
#  ' Chidambaram Palaniappan',
#  ' Chiratae Ventures',
#  ' Chiratae Ventures (formerly IDG Ventures)',
#  ' Cisco Investments',
#  ' Cisco Ventures',
#  ' Citi Ventures',
#  ' Citrus Payments',
#  ' Coatue Management',
#  ' Coleman and Co. Ltd (BCCL)',
#  ' Coleman and Company Ltd',
#  ' Coleman and Company Ltd (BCCL)',
#  ' Contrarian Capital',
#  ' Contrarian Capital India Partners',
#  ' Contrarian Vriddhi Fund',
#  ' Corvus Ventures',
#  ' Cota Capital',
#  ' Currae Healthtech Fund',
#  ' Cyber Carrier VC',
#  ' CyberAgent Ventures',
#  ' DG Incubation',
#  ' DG Ventures India',
#  ' DSG Consumer Partners',
#  ' DSG Consumer Partners and Venture Nursery',
#  ' DST Global',
#  ' DST Partners and RPS Ventures',
#  ' Dalip Pathak',
#  ' Dalip Pathak and Others',
#  ' Daljit Singh',
#  ' Darius Pandole',
#  ' Darrin Capital',
#  ' Darshak Shah',
#  ' Darshan Upadhyay',
#  ' Das Capital and IT Farm',
#  ' Daud Ali',
#  ' Daud Ali and others',
#  ' DeVry Inc',
#  ' Deep Kalra',
#  ' Deepak Chokhani',
#  ' Deepak Ghaisas',
#  ' Deepak Jain',
#  ' Deepak Natraj',
#  ' Deepak Sharma',
#  ' Deepak Singh',
#  ' Deepinder Goyal',
#  ' Delhivery',
#  ' Dena',
#  ' Deobrat Singh',
#  ' Deshe Holdings',
#  ' Deshpande Foundation',
#  ' Deutsche Telekom Strategic Investments (DTSI)',
#  ' Devendra Rane',
#  ' Devendra Reddy',
#  ' Dewan Housing Finance Corp',
#  ' Dexter Angel Circle',
#  ' Dheerag Jain',
#  ' Dheeraj Jain',
#  ' Dheeraj Mehta & Others',
#  ' Dhiraj Rajaram',
#  ' Dhruv Chitgopekar',
#  ' Diaz Nesamoney',
#  ' Didi Kuaidi',
#  ' Digital Currency Group',
#  ' Digital Garage',
#  ' Digital Garage Inc',
#  ' Dileep Nath',
#  ' Dilip Khandwelwal from SAP Labs India',
#  ' Dinesh Agarwal',
#  ' Dinesh Kundu & others',
#  ' Dinesh Mittal',
#  ' Dinesh R. Challa',
#  ' Dino Morea',
#  ' Divyesh Shah',
#  ' Doreswamy Nandkishore',
#  ' Dr Paresh Doshi',
#  ' Dr V Ravinder',
#  ' Dr. Aniruddha Malpani',
#  ' Dr. Apoorv Ranjan Sharma',
#  ' Dr. Pramath Raj Sinha',
#  ' Dr. Prasad Kaipa',
#  ' Dr. Ranjan Pai',
#  ' Dr. Ritesh Malik',
#  ' Draper Associates',
#  ' Draper Fisher Jurvetson',
#  ' Draphant Consultants',
#  ' Dream Incubator',
#  ' Dreamweaver Investments',
#  ' E-City VEntures Atul Goel',
#  ' E.ON',
#  ' EDBI',
#  ' Edelweiss Private Equity',
#  ' Edelweiss and Beenext',
#  ' Eight Innovate',
#  ' Eight Roads Ventures',
#  ' Eight Roads Ventures India',
#  ' Electronic Development Fund',
#  ' Elevar Equity',
#  ' Elevar Equity and Accel Partners',
#  ' Elevate Sports',
#  ' Emergent Ventures',
#  ' Emergent Ventures India',
#  ' Emergent Ventures and Y Combinator',
#  ' Empire Angels',
#  ' Endiya Partners',
#  ' Entrepreneurs India',
#  ' Esvee Technologies Inc',
#  ' Eureka Forbes Ltd',
#  ' European investment fund',
#  ' Evan Lim',
#  ' Excelsior Investments',
#  ' Exfinity Venture Partners & Others',
#  ' Exfinity Ventures',
#  ' Existing investors',
#  ' F-Prime Capital Partners',
#  ' FAO Ventures',
#  ' FIL Capital Management',
#  ' FJ Labs',
#  ' Faering Capital',
#  ' Falcon Edge',
#  ' Falcon Edge Capital',
#  ' Faraz Khan',
#  ' Farhan Naqvi',
#  ' Farooq Adam Mukadam',
#  ' Fauzan Rahim',
#  ' Fenqile',
#  ' Fidelity Biosciences',
#  ' Fidelity Growth Partners',
#  ' Fidelity Growth Partners India',
#  ' Fireside Ventures',
#  ' Flipkart',
#  ' Florintree Advisors',
#  ' Fortisure Ventures',
#  ' Fosun RZ Capital',
#  ' Foundation Capital',
#  ' Founder Collective',
#  ' Founders Fund',
#  ' Foxconn',
#  ' Foxconn Technology Group',
#  ' Franchise India Brands',
#  ' Fred Khosravi',
#  ' FreshMenu)',
#  ' Frontline Strategy',
#  ' Fullerton India Credit Company Ltd',
#  ' Fundnel',
#  ' Fusion Tech Ventures',
#  ' Fusiontech Ventures & Others',
#  ' G Ravishankar',
#  ' GFC',
#  ' GHV',
#  ' GHV Accelerator',
#  ' GREE Ventures',
#  ' GREE Ventures and Summit Media',
#  ' GSF and Other angel investors',
#  ' GVFL',
#  ' Gabriel Investments',
#  ' Gagan Dugal',
#  ' Gagan Goyal',
#  ' Gagan Hasteer ',
#  ' Ganpat Singhvi',
#  ' Gaurav Agarwal',
#  ' Gaurav Bhalotia',
#  ' Gaurav Bhatnagar',
#  ' Gaurav Bhogle',
#  ' Gaurav Dalmia',
#  ' Gaurav Gupta',
#  ' Gaurav Lochan',
#  ' Gaurav Luniya',
#  ' Gaurav Marya',
#  ' Gaurav Munjal',
#  ' Gaurav Sharma',
#  ' Gaurav Suri and Ankit Kesarwani',
#  ' Gaurav Vats',
#  ' Gautam Chhaochharia',
#  ' Gautam Gandhi',
#  ' Gautam Ivatury',
#  ' Gautam Sinha',
#  ' Girish Mathrubootham',
#  ' Girish Mathrubootham &\\\\xc2\\\\xa0 Group of other Angel investors',
#  ' Girish Matrubootham',
#  ' Girish Reddy',
#  ' Girnar Software',
#  ' Global Founders Capital',
#  ' Globeinvestor',
#  ' Globevestor',
#  ' Globevestor & others',
#  ' Goa',
#  ' Gokul Rajaram',
#  ' Goldbell Group',
#  ' Goldman Sachs',
#  ' Google Capital',
#  ' Google Capital & Accel Partners',
#  ' Govind Rajan & Others',
#  ' Grace Capital Ventures',
#  ' Great Oaks Ventures',
#  ' Green Shots Capital',
#  ' Greenoaks Capital',
#  ' Greenoaks Capital Partners',
#  ' Grey Orange',
#  ' Grey Orange Robotics',
#  ' Greycroft',
#  ' Greycroft Partners',
#  ' GrowX',
#  ' GrowX Ventures',
#  ' Gulpreet Kohli',
#  ' Gund Investment',
#  ' Gurmeet Chahal & Others',
#  ' Gurpreet Singh & others',
#  ' Gyanendra Singh',
#  ' H C Jain',
#  ' HDFC',
#  ' HDFC Asset Management',
#  ' HR Fund',
#  ' Hack VC',
#  ' Haitong Securities',
#  ' Haresh Chawla',
#  ' Harminder Sahani',
#  ' Harmony Partners',
#  ' Harpreet Singh Grover',
#  ' Harsh Kundra',
#  ' Harsh Mariwala',
#  ' Harvard Angels',
#  ' HealthQuad',
#  ' HealthQuad and Fireside Ventures',
#  ' Healthsquad',
#  ' Helion Advisors',
#  ' Helion Venture',
#  ' Helion Venture Partners',
#  ' Helion Ventures',
#  ' Hemant Kanakia',
#  ' Hemant Kaul',
#  ' Hemant Luthra',
#  ' Herb Madan',
#  ' Hercules Capital',
#  ' Hermes Group',
#  ' Hero Electronix\\\\xe2\\\\x80\\\\x99s corporate financing arm',
#  ' Hero Enterprise',
#  ' Hetal Sonpal',
#  ' Hillhouse Capital',
#  ' Himanshu Aggarwal',
#  ' Himanshu Aggrawal',
#  ' Hinduja Group',
#  ' Hinduja Leyland Finance and IntelleGrow',
#  ' Hiro Mashita',
#  ' Hirokazu',
#  ' Hitesh Gupta',
#  ' Hitesh Oberoi',
#  ' Holtzbrink Ventures',
#  ' Horizons Ventures',
#  ' Hornbill Orchid India Fund',
#  ' Horseferry',
#  ' Hrishi Oberoi',
#  ' Hrishikesh Parandekar',
#  ' Huang Wei',
#  ' Hyderabad Angels',
#  ' IA Venture Strategies Fund II LP',
#  ' IAN Fund',
#  ' IDFC-Parampara Capital',
#  ' IDFC-Parampara Fund',
#  ' IDG Venture',
#  ' IDG Ventures',
#  ' IDG Ventures & Advantedge fund',
#  ' IDG Ventures & Indian Angel Network',
#  ' IDG Ventures India',
#  ' IFC',
#  ' IFMR',
#  ' IIFL',
#  ' IIFL Wealth',
#  ' ILearnFinance Academy Pvt. Ltd.',
#  ' IMJ Investment Partners',
#  ' IMM Investment',
#  ' ITW Digital',
#  ' Ideation Initiative Pvt. Ltd',
#  ' Ignition Partners',
#  ' Imanpreet Singh Arora',
#  ' InMobi',
#  ' Inc',
#  ' Inc95 Consulting',
#  ' Incubation Foundation (SIIF)',
#  ' India Alternatives',
#  ' India Innovation Fund India Venture Partners',
#  ' India Internet Fund',
#  ' India Quotient',
#  ' Indian Angel Network',
#  ' Indian Angel Network (IAN)',
#  ' Individual Investors',
#  ' Indus Age Partners',
#  ' Infocomm Development Authority of Singapore',
#  ' Infocomm Investments',
#  ' Infosys Innovation Fund',
#  ' Infuse Ventures',
#  ' Innogy',
#  ' Innov8',
#  ' Innov8 founder Ritesh Malik',
#  ' Innoven Capital',
#  ' Intel Capital',
#  ' Intel Capital & Kae Capital',
#  ' IntelleGrow',
#  ' Intellecap Impact Investment Network',
#  ' International Finance Corporation (IFC)',
#  ' Internet Group',
#  ' Inventus Capital',
#  ' Inventus Capital Partners',
#  ' Investment AB Kinnevik',
#  ' Investopad',
#  ' IvyCap Ventures',
#  ' J.P. Bhatt',
#  ' JAFCO Asia',
#  ' JLL',
#  ' JM Financials and MEMG',
#  ' Jagdish & Sandeep Mehta Family Office',
#  ' Jagdish Kumar',
#  ' Jaikumar Nair',
#  ' Jairaj Singh',
#  ' Jamil Khatri',
#  ' Jarett Posner',
#  ' Jason Hirschhorn',
#  ' Jaspreet Bindra',
#  ' Jatin Aneja',
#  ' Jay Sethuram',
#  ' Jay Srinivasan',
#  ' Jayant Davar',
#  ' Jayant Kadambi',
#  ' Jayesh Parekh',
#  ' Jayesh Shah',
#  ' Jaysukh Sapra',
#  ' Jeevanandhan Rajagopal',
#  ' Jeroen Mensen',
#  ' Jim Schimdktke',
#  ' Jitendra Gupta',
#  ' Jitendra Gupta & Others',
#  ' Joby Babu',
#  ' John Katzman',
#  ' Jonathan Boutelle',
#  ' Josh Talks founders Supriya Paul and Shobha Banga',
#  ' Jr. Millennium Trust',
#  ' Jungle Venture Partners',
#  ' Jungle Ventures',
#  ' Jungle Ventures & Bessemer Venture Partners',
#  ' Jyoti Bansal',
#  ' K Ganesh',
#  ' KCK Global & Others',
#  ' KK Mehra',
#  ' Kae Capital',
#  ' Kae Capital & Others',
#  ' Kalaari Capital',
#  ' Kalaari Capital and IDG Ventures India',
#  ' Kalaari Capital and Inventus Capital',
#  ' Kalaari Capital and Others',
#  ' Kalaari Capital and Private equity firm Multiples Alternate Asset Management',
#  ' Kalpana Tatavarti',
#  ' Kamal Bansal',
#  ' Kamal Chabra',
#  ' Kamal Kothari',
#  ' Kamal Puri',
#  ' Kanchan Ghoshal',
#  ' Kanwaljit Singh',
#  ' Kapil Hetamsaria',
#  ' Karan Chellani',
#  ' Karan Maheshwari',
#  ' Karthee Madasamay',
#  ' Kartik Hosanagar',
#  ' Kashyap Deorah',
#  ' Keiretsu Forum & Others',
#  ' Keith Rodricks',
#  ' Keshav Sanghi',
#  ' Khattar Holdings',
#  ' Khazanah Nasional Berhad',
#  ' Khosla Impact',
#  ' Khosla Ventures',
#  ' Kima Ventures',
#  ' Kinzon Capital',
#  ' Kiran Deshpande',
#  ' Kiran Mazumdar-Shaw',
#  ' Kiran Shetty',
#  ' Kishor Ganji',
#  ' Kishore Ganji',
#  ' Kishore Kumar',
#  ' Kiyohiro Sugashita',
#  ' Knoll Ventures and others',
#  ' Konly Venture',
#  ' Kris Gopalakrishnan',
#  ' Krish Seshadri',
#  ' Krishan Gupta & Others',
#  ' Krishna Jhunjhunwaala',
#  ' Krishna Jhunjhunwala',
#  ' Krishna Mehra',
#  ' Krishnakumar Nataraj',
#  ' Krishnakumar Natarajan',
#  ' Krit Sankalp',
#  ' Kshitij Arora',
#  ' Kshitij Jain',
#  ' Kumar Shwetabh',
#  ' Kumar Vembu',
#  ' Kunal Bahl',
#  ' Kunal Khattar',
#  ' Kunal Shah',
#  ' Kunal Shah & Sandeep Tandon',
#  ' Kunal Shah and Manish Patel.',
#  ' L.D Sharma',
#  ' LG Chandrasekhar',
#  ' LGT Impact',
#  ' LGT Impact Ventures',
#  ' LN Buddharaju',
#  ' LV Prasad',
#  ' Lakshmi Narayanan',
#  ' Lalit Mangal',
#  ' Larry Braitman',
#  ' Lasmer NV',
#  ' Lead Angels',
#  ' Lead Angels & Others',
#  ' Lead Angels Group & Others',
#  ' LeapFrog Investments',
#  ' Learn Capital',
#  ' Leo Wang Sangeeth Ram',
#  ' Leon Seynave',
#  ' Let\\\\xe2\\\\x80\\\\x99s Venture',
#  ' LetsVenture',
#  ' LetsVenture & Others',
#  ' LetsVenture investors',
#  ' Li Jian',
#  ' Liberty Media',
#  ' LightStreet',
#  ' Lightbox',
#  ' Lightbox Expansion Fund',
#  ' Lightbridge Partners & Kairos',
#  ' Lightspeed India',
#  ' Lightspeed US',
#  ' Lightspeed Venture Partners',
#  ' Lightspeed Ventures',
#  ' Likemind Ventures',
#  ' Line Corp',
#  ' Liquid 2 Ventures',
#  ' Littlerock',
#  ' Lok Capital',
#  ' Lomesh Agarwal',
#  ' Low Carbon Enterprise Fund',
#  ' Lumina Datamatics',
#  ' Lumis Partners',
#  ' M & S partners',
#  ' M George Oommen',
#  ' M&S Partners',
#  ' M&S Partners & others',
#  ' MAPE Advisory Group',
#  ' MEMG CDC',
#  ' MEMG Family Office',
#  ' MGV',
#  ' MJ Aravind',
#  ' MMY co-Founder',
#  ' Madhusudan E',
#  ' Madhusudhan Jujare & Others',
#  ' Madhusudhan Kannan',
#  ' Mahavir Pratap Sharma',
#  ' Mahavir Sharma',
#  ' Mahendra Doshi',
#  ' Mahesh Kothurkar',
#  ' Mahesh Murthy',
#  ' Maheshwar Peri',
#  ' Maheshwari Investments Pvt Ltd',
#  ' Maiden Lane Ventures',
#  ' MakeMyTrip',
#  ' Malvinder and Shivinder Singh',
#  ' Mamoru Taniya',
#  ' Mandar Mhatre',
#  ' Mandhian family & Others',
#  ' Manickam Mahalingam',
#  ' Maninder Gulati',
#  ' Manish Amin',
#  ' Manish Dhingra',
#  ' Manish Dugar',
#  ' Manish Gandhi',
#  ' Manish Kheterpal',
#  ' Manish Prasad',
#  ' Manish Shah',
#  ' Manish Singhal',
#  ' Manish Vij',
#  ' Manisha Gupta',
#  ' Manoj Varghese',
#  ' Mantra Ventures',
#  ' Manvinder Singh Banga',
#  ' Mape Advisory Group',
#  ' March Capital',
#  ' Mariwala family',
#  ' Mathew Cyriac',
#  ' Mato Peric',
#  ' Mato Peric & Others',
#  ' Matrix Partners',
#  ' Matrix Partners India',
#  ' Matrix Partners India and Zodius Capital',
#  ' Maverick Capital Ltd and HBM Healthcare Investments Ltd',
#  ' Maverick Capital Ventures',
#  ' Mayank Bhangdia',
#  ' Mayank Mittal & Others',
#  ' Mayank Singhal',
#  ' Mayfield',
#  ' Mayfield & Others',
#  ' Mayfield Capital',
#  ' Mayfield India',
#  ' Mayfield Ventures',
#  ' Mayur Abhaya',
#  ' MediAssist',
#  ' MediaTek',
#  ' Meet Kanodia',
#  ' Mekin Maheshwari',
#  ' MeraEvents.',
#  ' Michael & Susan Dell Foundation',
#  ' Michael Carlos',
#  ' Michael Herzig',
#  ' Michael Marks',
#  ' Michael and Susan Dell Foundation',
#  ' Micro venture capital firm GEMS Partners and Others',
#  ' Micromax',
#  ' Micromax Informatics',
#  ' Mike Galgon',
#  ' Mike Shah',
#  ' Milind Chaudhary',
#  ' Milind Sarwate',
#  ' Milliways Ventures',
#  ' Mistletoe',
#  ' Mitali Pawar',
#  ' Miten Mehta',
#  ' Mitesh Shah',
#  ' Mohan Alexander',
#  ' Mohandas Pai',
#  ' Mohandas Pai. Pallav Nadhani',
#  ' Mohit Agarwal',
#  ' Mohit Gupta',
#  ' Mohit Satyan',
#  ' Mohit Satyanand',
#  ' Mohit Satyanand & others',
#  ' Mohit Saxena',
#  ' Moksh Sports Ventures',
#  ' Mount Nathan Advisors',
#  ' Mountain Pine Capital',
#  ' Mousse Partners',
#  ' Mr. Praveen Someshwar',
#  ' Mridul Upreti',
#  ' Mukul Singhal',
#  ' Multiples Alternate Asset Management',
#  ' Mumbai Angel',
#  ' Mumbai Angels',
#  ' Mumbai Angels MAPE Advisory Group.',
#  ' Mumbai Angels Network',
#  ' Munish Jauhar',
#  ' Murali Nair',
#  ' Mustafa Patni',
#  ' Myntra) and Mitesh Shah (finance chief',
#  ' N Squared Management LLC',
#  ' NB Ventures',
#  ' NEA',
#  ' NEA Ventures',
#  ' NGP',
#  ' NPTK',
#  ' NR Narayana Murthy.',
#  ' NY based Hedge Fund',
#  ' Nagendra Chaudhary',
#  ' Nagendra Prasad Bhanuprakash',
#  ' Naman Sarawagi',
#  ' Namrata Kaul',
#  ' Nandan Nilekani',
#  ' Nandan Nilekani\\\\xe2\\\\x80\\\\x99s NRJN Trust',
#  ' Nandkumar Rane',
#  ' Nandu Nandkishore',
#  ' Narayan Ramachandran',
#  ' Narayan Seshadri',
#  ' Narendra Karnavat',
#  ' Naresh Ravindranath',
#  ' Native Angels Network',
#  ' Naveen Tewari',
#  ' Naveen Tiwari',
#  ' Naver',
#  ' Navjot Saini',
#  ' Navneet Education and Mahavir Agency',
#  ' Naya Ventures',
#  ' Nazara Technologies',
#  ' Neelesh Bhatnagar',
#  ' Neeraj Aggarwal',
#  ' Neeraj Arora',
#  ' Neeraj Goenka',
#  ' Neeraj Jawalkar',
#  ' Neoplux Technology Fund',
#  ' Ness Wadia',
#  ' Network 18',
#  ' New Enterprise Associates',
#  ' New Enterprise Associates (NEA)',
#  ' New India Investment Corporation',
#  ' Newfort Capital',
#  ' Nexus India Capital Advisors',
#  ' Nexus Venture Partners',
#  ' Nexus Venture Partners and Arena Ventures',
#  ' Nexus Venture Partners and Blume Ventures',
#  ' Nexus Ventures',
#  ' Nexus venture Partners',
#  ' Nick Haulkoury',
#  ' Nicolas Braithwaite',
#  ' Nikhil Arora',
#  ' Nikhil Bagri',
#  ' Nikhil G and Bhavesh P',
#  ' Nikhil Golcha',
#  ' Nikhil Vora',
#  ' Nikhil Vora & others',
#  ' Nikunj Jain',
#  ' Nikunj Jhaveri',
#  ' Nilender Chauhan',
#  ' Nimitt Desai & Others',
#  ' Nipun Dureja',
#  ' Niraj Singh',
#  ' Nirav Choksi & Others',
#  ' Nirmal Singh',
#  ' Nirupa Shankar',
#  ' Nirvana Digital India Fund',
#  ' Nirvana Digital Investment Holding',
#  ' Nirvana Digital Investment Holding Co Ltd',
#  ' Nishant Rao',
#  ' Nitesh Pant',
#  ' Nitin Agarwal',
#  ' Nitin Garg',
#  ' Nitin Saluja',
#  ' Nitish Singh',
#  ' Nobel House',
#  ' North Base Media',
#  ' Norwest Venture Partners',
#  ' Nspira',
#  ' Nyca Partners and Thomvest Ventures',
#  ' ONCOTRUST and Medintel Services Pvt. Ltd',
#  ' OPPO',
#  ' Oikocredit',
#  ' Omidiyar Network',
#  ' Omidyar Network',
#  ' Omidyar Network and Accion Venture Labs',
#  ' Omidyar Network and Kae Capital',
#  ' Omidyar Network and Kaizen Private Equity also participated in the round',
#  ' Omidyar Network and Shunwei Capital',
#  ' Omidyar Network.',
#  ' Omidyar Networks',
#  ' Omnivore',
#  ' Ontario Teachers\\\\\'"',
#  ' Orios Venture Partners',
#  ' Orios Venture Partners and the IAN Fund',
#  ' Orios Venture Partners.',
#  ' Others',
#  ' Others from LetsVenture',
#  ' Outbox Ventures',
#  ' P.V SIndhu',
#  ' P39 Capital',
#  ' P39 Capital & Others',
#  ' PK Gulati & others',
#  ' PS1 Venture and GlobalLogic co-founder Rajul Garg',
#  ' PV Srinivasan',
#  ' Pablo van den Bosch & Others',
#  ' Palash Jain',
#  ' Pallab Chatterjee & others',
#  ' Pallav Nadhani',
#  ' Pallav Pandey',
#  ' Pameela P',
#  ' Pankaj Gupta',
#  ' Pankaj Kapoor',
#  ' Pankaj Tripathi',
#  ' Paragon Partners',
#  ' Paragon Trust',
#  ...]

# %%
df['investors']
# Out:
# Sr No
# 1                                 Tiger Global Management
# 2                               Susquehanna Growth Equity
# 3                                   Sequoia Capital India
# 4                                          Vinod Khatumal
# 5                                 Sprout Venture Partners
#                               ...
# 2869                                        SAIF Partners
# 2870    Sumit Jain, Aprameya Radhakrishna, Alok Goel, ...
# 2871                                           Rainmatter
# 2872                                          The HR Fund
# 2873             Bessemer Venture Partners, SAIF Partners
# Name: investors, Length: 2821, dtype: object

# %%
df.sort_values(by='date',ascending=False)[df['investors'].str.contains('Softbank')].head()[['date','startup','subvertical','city','round','amount']]
# Out:
# C:\Users\wajid\AppData\Local\Temp\ipykernel_22708\1909330100.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.sort_values(by='date',ascending=False)[df['investors'].str.contains('Softbank')].head()[['date','startup','subvertical','city','round','amount']]
#             date       startup                     subvertical       city  \
# Sr No
# 60    2019-08-19       Grofers                Grocery Delivery    Gurgaon
# 142   2018-11-24   Engineer.ai                     AI Platform   India/US
# 652   2017-11-08      Flipkart              Online Marketplace  Bangalore
# 524   2017-03-10      Ola Cabs  App based cab hailing services  Bangalore
# 1034  2017-02-21  True Balance     Mobile balance Checking App    Gurgaon
#
#                 round      amount
# Sr No
# 60           Series F    593.1100
# 142          Series A    249.9535
# 652    Private Equity  21182.5000
# 524    Private Equity    932.0300
# 1034   Private Equity    127.0950

# %%
df[df['investors'].str.contains('Softbank')][['date','startup','subvertical','city','round','amount']].sort_values\
(by='date',ascending=False).head()
# Out:
#             date       startup                     subvertical       city  \
# Sr No
# 60    2019-08-19       Grofers                Grocery Delivery    Gurgaon
# 142   2018-11-24   Engineer.ai                     AI Platform   India/US
# 652   2017-11-08      Flipkart              Online Marketplace  Bangalore
# 524   2017-03-10      Ola Cabs  App based cab hailing services  Bangalore
# 1034  2017-02-21  True Balance     Mobile balance Checking App    Gurgaon
#
#                 round      amount
# Sr No
# 60           Series F    593.1100
# 142          Series A    249.9535
# 652    Private Equity  21182.5000
# 524    Private Equity    932.0300
# 1034   Private Equity    127.0950

# %%
df[df['investors'].str.contains('Softbank')].groupby(['startup'])['amount'].sum().sort_values(ascending=False).head()
# Out:
# startup
# Flipkart    21182.500
# Snapdeal     4236.500
# Ola Cabs     2838.455
# Grofers      1609.870
# Oyo           847.300
# Name: amount, dtype: float64

# %%
df[df['investors'].str.contains('Softbank')].groupby(['subvertical'])['amount'].sum().sort_values(ascending=False).head()
# Out:
# subvertical
# Online Marketplace                            21182.5000
# App based cab hailing services                  932.0300
# Online Branded Budget Room Booking Service      847.3000
# Grocery Delivery                                593.1100
# AI Platform                                     249.9535
# Name: amount, dtype: float64

# %%
df['year']=df['date'].dt.year
# Out:
# C:\Users\wajid\AppData\Local\Temp\ipykernel_22708\2063528821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year']=df['date'].dt.year

# %%
df[df['investors'].str.contains('Softbank')].groupby(['year'])['amount'].sum().sort_values(ascending=False).head().plot()
# Out:
# <Axes: xlabel='year'>

# %%
round(df['amount'].sum())
# Out:
# 304453

# %%
round(df['amount'].max())
# Out:
# 33045

# %%
round(df['amount'].mean())
# Out:
# 108

# %%
df['startup'].nunique()
# Out:
# 2298

# %%
df['month']=df['date'].dt.month
# Out:
# C:\Users\wajid\AppData\Local\Temp\ipykernel_22708\4289079944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month']=df['date'].dt.month

# %%
df
# Out:
#             date                       startup                    industry  \
# Sr No
# 1     2020-09-01                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-09-01                     Mamaearth                  E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/                     FinTech
# 5     2020-02-01                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
# ...                                      ...        ...
# 2869                                     NaN  Bangalore
# 2870                                     NaN  Bangalore
# 2871                                     NaN  Bangalore
# 2872                                     NaN    Chennai
# 2873                                     NaN      Noida
#
#                                                investors  \
# Sr No
# 1                                Tiger Global Management
# 2                              Susquehanna Growth Equity
# 3                                  Sequoia Capital India
# 4                                         Vinod Khatumal
# 5                                Sprout Venture Partners
# ...                                                  ...
# 2869                                       SAIF Partners
# 2870   Sumit Jain, Aprameya Radhakrishna, Alok Goel, ...
# 2871                                          Rainmatter
# 2872                                         The HR Fund
# 2873            Bessemer Venture Partners, SAIF Partners
#
#                       round       amount  year  month
# Sr No
# 1      Private Equity Round  1694.600000  2020      9
# 2                  Series C    68.194042  2020      1
# 3                  Series B   155.554621  2020      9
# 4              Pre-series A    25.419000  2020      2
# 5                Seed Round    15.251400  2020      2
# ...                     ...          ...   ...    ...
# 2869         Private Equity    29.655500  2015      4
# 2870           Seed Funding     0.000000  2015      4
# 2871           Seed Funding     3.389200  2015      4
# 2872           Seed Funding     4.236500  2015      4
# 2873         Private Equity    67.784000  2015      4
#
# [2821 rows x 10 columns]

# %%
temp=df.groupby(['year','month'])['amount'].sum().reset_index()
temp
# Out:
#     year  month       amount
# 0   2015      1  5417.212550
# 1   2015      2  1609.539553
# 2   2015      3  1962.304435
# 3   2015      4  4632.994035
# 4   2015      5  1439.308510
# ..   ...    ...          ...
# 58  2019     12  3766.248500
# 59  2020      1   144.451042
# 60  2020      2    40.670400
# 61  2020      9  1850.154621
# 62  2020     10  1270.950000
#
# [63 rows x 3 columns]

# %%
temp['x_axis']=temp['month'].astype(str)+'-'+temp['year'].astype(str)

# %%
temp
# Out:
#     year  month       amount   x_axis
# 0   2015      1  5417.212550   1-2015
# 1   2015      2  1609.539553   2-2015
# 2   2015      3  1962.304435   3-2015
# 3   2015      4  4632.994035   4-2015
# 4   2015      5  1439.308510   5-2015
# ..   ...    ...          ...      ...
# 58  2019     12  3766.248500  12-2019
# 59  2020      1   144.451042   1-2020
# 60  2020      2    40.670400   2-2020
# 61  2020      9  1850.154621   9-2020
# 62  2020     10  1270.950000  10-2020
#
# [63 rows x 4 columns]

# %%
df.groupby(['year','month'])['startup'].count()
# Out:
# year  month
# 2015  1        35
#       2        14
#       3        36
#       4        65
#       5        53
#                ..
# 2019  12       10
# 2020  1         2
#       2         2
#       9         2
#       10        1
# Name: startup, Length: 63, dtype: int64

# %%
df.groupby(['year','month'])['amount'].count()
# Out:
# year  month
# 2015  1        35
#       2        14
#       3        36
#       4        65
#       5        53
#                ..
# 2019  12       10
# 2020  1         2
#       2         2
#       9         2
#       10        1
# Name: amount, Length: 63, dtype: int64

# %%
df
# Out:
#             date                       startup                    industry  \
# Sr No
# 1     2020-09-01                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-09-01                     Mamaearth                  E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/                     FinTech
# 5     2020-02-01                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
# ...                                      ...        ...
# 2869                                     NaN  Bangalore
# 2870                                     NaN  Bangalore
# 2871                                     NaN  Bangalore
# 2872                                     NaN    Chennai
# 2873                                     NaN      Noida
#
#                                                investors  \
# Sr No
# 1                                Tiger Global Management
# 2                              Susquehanna Growth Equity
# 3                                  Sequoia Capital India
# 4                                         Vinod Khatumal
# 5                                Sprout Venture Partners
# ...                                                  ...
# 2869                                       SAIF Partners
# 2870   Sumit Jain, Aprameya Radhakrishna, Alok Goel, ...
# 2871                                          Rainmatter
# 2872                                         The HR Fund
# 2873            Bessemer Venture Partners, SAIF Partners
#
#                       round       amount  year  month
# Sr No
# 1      Private Equity Round  1694.600000  2020      9
# 2                  Series C    68.194042  2020      1
# 3                  Series B   155.554621  2020      9
# 4              Pre-series A    25.419000  2020      2
# 5                Seed Round    15.251400  2020      2
# ...                     ...          ...   ...    ...
# 2869         Private Equity    29.655500  2015      4
# 2870           Seed Funding     0.000000  2015      4
# 2871           Seed Funding     3.389200  2015      4
# 2872           Seed Funding     4.236500  2015      4
# 2873         Private Equity    67.784000  2015      4
#
# [2821 rows x 10 columns]

# %%
df[df['startup']=='BYJU’S']
# Out:
#             date startup industry subvertical       city  \
# Sr No
# 1     2020-09-01  BYJU’S   E-Tech  E-learning  Bengaluru
#
#                      investors                 round  amount  year  month
# Sr No
# 1      Tiger Global Management  Private Equity Round  1694.6  2020      9

# %%
df[df['startup']=='BYJU’S']['industry']
# Out:
# Sr No
# 1    E-Tech
# Name: industry, dtype: object

# %%
x=df[df['startup']=='ABI Health']['industry']

# %%
x
# Out:
# Sr No
# 736    Technology
# Name: industry, dtype: object

# %%
df[df['startup']=='ABI Health']['industry']
# Out:
# Sr No
# 736    Technology
# Name: industry, dtype: object

# %%
list(x)
# Out:
# ['Technology']

# %%
x
# Out:
# Sr No
# 736    Technology
# Name: industry, dtype: object

# %%
w=list(x)

# %%
type(w)
# Out:
# list

# %%
w
# Out:
# ['Technology']
